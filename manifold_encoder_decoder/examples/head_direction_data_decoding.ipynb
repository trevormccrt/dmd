# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from sklearn import decomposition
import sys
import torch

sys.path.append(os.path.join(os.getenv("HOME"), "RNN_Manifold/"))
from manifold_encoder_decoder import s1_direct_product_decoder, geometry_util

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# First, load the data. In this notebook I am using data from Mouse 28-140313 (same as nature paper fig.2). The only preprocessing that has been applied is a smoothing of spikes to produce rates.

# %%
data_dir = "/home/trevor/manifold_test_data/experimental_ring_data"
data = np.squeeze(np.load(os.path.join(data_dir, "encoded_points.npy")))
angles = np.squeeze(np.load(os.path.join(data_dir, "true_phases.npy")))

# %% [markdown]
# Linear dimensionality reduction helps to mitigate the effects of bottlenecking in the model

# %%
pca_instance = decomposition.PCA(n_components=10)
proj_data = pca_instance.fit_transform(np.sqrt(data))
normed_rates = proj_data/np.mean(np.abs(proj_data))

# %% [markdown]
# Fit the manifold

# %%
decoder_hidden_size = 1000
encoder_hidden_size = int(1.5 * decoder_hidden_size)
decoder_n_hidden = 2
encoder_n_hidden = decoder_n_hidden

# %%
encoder, decoder = s1_direct_product_decoder.train(data=normed_rates, manifold_dim=1, device=device,
                                                   n_training_iterations=500, decoder_weight=10, order_red_weight=0.1, batch_size=50, encoder_hidden_dim=encoder_hidden_size, encoder_n_hidden=encoder_n_hidden, decoder_hidden_dim=decoder_hidden_size, decoder_n_hidden=decoder_n_hidden)
# Out:
# iteration: 0, decoding loss: 2.2618420124053955, distance cost: 0.005008587148040533, order reduction: 0.0028103848453611135
# iteration: 3, decoding loss: 1.784527063369751, distance cost: 0.022113457322120667, order reduction: 0.004092501010745764
# iteration: 4, decoding loss: 1.663695216178894, distance cost: 0.013502739369869232, order reduction: 0.0023260849993675947
# iteration: 6, decoding loss: 1.3322794437408447, distance cost: 0.04725990816950798, order reduction: 0.0045984527096152306
# iteration: 7, decoding loss: 1.3205362558364868, distance cost: 0.050055742263793945, order reduction: 0.0026555084623396397
# iteration: 9, decoding loss: 1.046162724494934, distance cost: 0.00825362280011177, order reduction: 0.0022657900117337704
# iteration: 11, decoding loss: 1.0034985542297363, distance cost: 0.02799610048532486, order reduction: 0.002135386224836111
# iteration: 12, decoding loss: 0.9538807272911072, distance cost: 0.04393879324197769, order reduction: 0.002906578127294779
# iteration: 13, decoding loss: 0.9474368095397949, distance cost: 0.04763117432594299, order reduction: 0.0024331833701580763
# iteration: 14, decoding loss: 0.8472781181335449, distance cost: 0.036863237619400024, order reduction: 0.003946720156818628
# iteration: 16, decoding loss: 0.8217179775238037, distance cost: 0.031232072040438652, order reduction: 0.0033786986023187637
# iteration: 17, decoding loss: 0.8126469254493713, distance cost: 0.040713898837566376, order reduction: 0.003998547326773405
# iteration: 18, decoding loss: 0.7360583543777466, distance cost: 0.033320192247629166, order reduction: 0.0033470038324594498
# iteration: 22, decoding loss: 0.6820792555809021, distance cost: 0.025526056066155434, order reduction: 0.004339328035712242
# iteration: 23, decoding loss: 0.674868643283844, distance cost: 0.02813560701906681, order reduction: 0.004858805797994137
# iteration: 24, decoding loss: 0.6369083523750305, distance cost: 0.02563258819282055, order reduction: 0.004391114227473736
# iteration: 25, decoding loss: 0.6345098614692688, distance cost: 0.022494511678814888, order reduction: 0.004178138449788094
# iteration: 26, decoding loss: 0.6228259801864624, distance cost: 0.022996149957180023, order reduction: 0.005005675833672285
# iteration: 27, decoding loss: 0.6140947341918945, distance cost: 0.020743804052472115, order reduction: 0.004449967294931412
# iteration: 28, decoding loss: 0.5847593545913696, distance cost: 0.017607320100069046, order reduction: 0.004836633801460266
# iteration: 29, decoding loss: 0.5757805705070496, distance cost: 0.021607600152492523, order reduction: 0.005436882376670837
# iteration: 31, decoding loss: 0.5585572123527527, distance cost: 0.0173947811126709, order reduction: 0.0055667017586529255
# iteration: 33, decoding loss: 0.547651469707489, distance cost: 0.011181785725057125, order reduction: 0.006588838994503021
# iteration: 34, decoding loss: 0.5324108004570007, distance cost: 0.011529194191098213, order reduction: 0.0067314752377569675
# iteration: 35, decoding loss: 0.5274560451507568, distance cost: 0.010763258673250675, order reduction: 0.0066358428448438644
# iteration: 37, decoding loss: 0.5061784982681274, distance cost: 0.011018600314855576, order reduction: 0.0077386051416397095
# iteration: 38, decoding loss: 0.4582095146179199, distance cost: 0.013243962079286575, order reduction: 0.007194853387773037
# iteration: 40, decoding loss: 0.4339882731437683, distance cost: 0.016215799376368523, order reduction: 0.007476389408111572
# iteration: 41, decoding loss: 0.4229706823825836, distance cost: 0.018828820437192917, order reduction: 0.007865788415074348
# iteration: 43, decoding loss: 0.3976690471172333, distance cost: 0.01954602263867855, order reduction: 0.00933748111128807
# iteration: 44, decoding loss: 0.39147329330444336, distance cost: 0.017838254570961, order reduction: 0.00873823557049036
# iteration: 45, decoding loss: 0.3838772475719452, distance cost: 0.01743929460644722, order reduction: 0.009646229445934296
# iteration: 46, decoding loss: 0.3672640323638916, distance cost: 0.02413882501423359, order reduction: 0.009231466799974442
# iteration: 47, decoding loss: 0.3575727641582489, distance cost: 0.02743588387966156, order reduction: 0.009267281740903854
# iteration: 49, decoding loss: 0.33511120080947876, distance cost: 0.03229908645153046, order reduction: 0.010113537311553955
# iteration: 50, decoding loss: 0.3345516622066498, distance cost: 0.03053739294409752, order reduction: 0.010450129397213459
# iteration: 51, decoding loss: 0.3336377739906311, distance cost: 0.03460337966680527, order reduction: 0.009898897260427475
# iteration: 52, decoding loss: 0.31349748373031616, distance cost: 0.03962571918964386, order reduction: 0.010626349598169327
# iteration: 53, decoding loss: 0.30413389205932617, distance cost: 0.04144703969359398, order reduction: 0.011027202941477299
# iteration: 54, decoding loss: 0.2952152490615845, distance cost: 0.05261871591210365, order reduction: 0.012695626355707645
# iteration: 57, decoding loss: 0.28417104482650757, distance cost: 0.053431231528520584, order reduction: 0.014258000999689102
# iteration: 63, decoding loss: 0.2744741141796112, distance cost: 0.05321156606078148, order reduction: 0.014066244475543499
# iteration: 64, decoding loss: 0.27263569831848145, distance cost: 0.05180719867348671, order reduction: 0.014105151407420635
# iteration: 73, decoding loss: 0.2620429992675781, distance cost: 0.08617369085550308, order reduction: 0.01626342162489891
# iteration: 74, decoding loss: 0.2592228353023529, distance cost: 0.0895514115691185, order reduction: 0.014840565621852875
# iteration: 75, decoding loss: 0.25489598512649536, distance cost: 0.10369501262903214, order reduction: 0.01533034909516573
# iteration: 76, decoding loss: 0.25258979201316833, distance cost: 0.10518520325422287, order reduction: 0.01740610972046852
# iteration: 78, decoding loss: 0.25242146849632263, distance cost: 0.10048811137676239, order reduction: 0.014307783916592598
# iteration: 79, decoding loss: 0.24342501163482666, distance cost: 0.10459379106760025, order reduction: 0.016658805310726166
# iteration: 80, decoding loss: 0.23170235753059387, distance cost: 0.10860467702150345, order reduction: 0.01634831167757511
# iteration: 82, decoding loss: 0.23053714632987976, distance cost: 0.09463316947221756, order reduction: 0.016100989654660225
# iteration: 86, decoding loss: 0.22788505256175995, distance cost: 0.0912245661020279, order reduction: 0.015211120247840881
# iteration: 89, decoding loss: 0.2197633534669876, distance cost: 0.09951414912939072, order reduction: 0.017634907737374306
# iteration: 92, decoding loss: 0.21933504939079285, distance cost: 0.10141472518444061, order reduction: 0.018559755757451057
# iteration: 99, decoding loss: 0.21777573227882385, distance cost: 0.0886441245675087, order reduction: 0.01901664398610592
# iteration: 162, decoding loss: 0.22009894251823425, distance cost: 0.06178480014204979, order reduction: 0.020445387810468674
# iteration: 164, decoding loss: 0.2198772430419922, distance cost: 0.05903153494000435, order reduction: 0.022815877571702003
# iteration: 167, decoding loss: 0.21242697536945343, distance cost: 0.06377776712179184, order reduction: 0.019592812284827232
# iteration: 194, decoding loss: 0.21179433166980743, distance cost: 0.05543525144457817, order reduction: 0.024166172370314598
# iteration: 207, decoding loss: 0.21001805365085602, distance cost: 0.04956303536891937, order reduction: 0.025928808376193047
# iteration: 211, decoding loss: 0.20926666259765625, distance cost: 0.04581298679113388, order reduction: 0.027307068929076195
# iteration: 237, decoding loss: 0.20838366448879242, distance cost: 0.03469249978661537, order reduction: 0.024961154907941818
# iteration: 250, decoding loss: 0.20565356314182281, distance cost: 0.030445875599980354, order reduction: 0.025439299643039703
# iteration: 255, decoding loss: 0.19822382926940918, distance cost: 0.02711256965994835, order reduction: 0.0213679950684309
# iteration: 256, decoding loss: 0.19778557121753693, distance cost: 0.030708415433764458, order reduction: 0.023032234981656075

# %% [markdown]
# If it doesn't get stuck we should end up with a decoding loss of around 0.2 for this dataset. We can do some random projections of the results

# %%
n_projections = 6
embed_dim = np.shape(normed_rates)[1]
random_projections = np.random.normal(0, 1, (n_projections, 2, embed_dim))
col_norm = np.einsum("ijk, ijk -> ik", random_projections, random_projections)
normed_proj = np.einsum("ijk, ik -> ijk", random_projections, 1/np.sqrt(col_norm))
projected_data = np.einsum("bk, ijk -> bij", normed_rates, normed_proj)

# %%
test_angles = np.linspace(start=0, stop=2 * np.pi, num=1000)
test_points = np.expand_dims(geometry_util.angles_to_ring(test_angles), -2)
with torch.no_grad():
    test_embedding = encoder(torch.tensor(test_points, dtype=torch.get_default_dtype()).to(device))
test_embedding = test_embedding.cpu().numpy()
projected_test_embedding = np.einsum("bk, ijk -> bij", test_embedding, normed_proj)

# %%
data_plot_density = 1
fig, axs = plt.subplots(ncols=n_projections)
for i in range(n_projections):
    axs[i].scatter(projected_data[::data_plot_density, i, 0], projected_data[::data_plot_density, i, 1], color="C0")
    axs[i].plot(projected_test_embedding[:, i, 0], projected_test_embedding[:, i, 1], color="C1")

# %% [markdown]
# These generally aren't that useful: if they were, PCA alone would probably be enough to reveal the ring structure.
#
# Now compare to ground-truth head direction information

# %%
with torch.no_grad():
    decoded_points, decoded_angles = decoder(torch.tensor(normed_rates, dtype=torch.get_default_dtype()).to(device))

predicted_phases = torch.squeeze(decoded_angles).cpu().numpy()

# %%
def reference_phases(phases):
    phases_refd = phases - phases[0]
    phases_refd = np.arctan2(np.sin(phases_refd), np.cos(phases_refd))
    return phases_refd * np.sign(phases_refd[1])

def compare_to_ground_truth(predicted_phases, ground_truth_phases, plot_ax):
    refd_test_phases = reference_phases(predicted_phases)
    refd_true_phases = reference_phases(ground_truth_phases)
    line = np.arange(start=-np.pi, stop=np.pi, step=0.01)
    plot_ax.scatter(refd_true_phases, refd_test_phases)
    plot_ax.plot(line, line, color="black", linestyle="--", label="y=x")
    plot_ax.set_xlabel("True Phase")
    plot_ax.set_ylabel("Found Phase")
    return refd_test_phases, refd_true_phases

# %%
fig, axs = plt.subplots()
refd_pred, refd_data = compare_to_ground_truth(predicted_phases, angles, axs)

# %% [markdown]
# If the decoding worked, the data should be randomly and evenly distributed around the line y=x (or y=-x if the sign convention is detected incorrectly). If this is the case, the residual error is due to noise. Alternatively, in histogram form,

# %%
with torch.no_grad():
    errors, _, _ = geometry_util.minimum_periodic_distance(torch.Tensor(np.expand_dims(refd_pred, -1)), torch.Tensor(np.expand_dims(refd_data, -1)))
fig, axs = plt.subplots()
axs.hist(errors)
axs.set_xlabel("Prediction error")
axs.set_ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')
